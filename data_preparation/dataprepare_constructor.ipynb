# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np

races_csv = "/content/drive/MyDrive/Colab Notebooks/archive/races.csv"
constructor_results_csv = "/content/drive/MyDrive/Colab Notebooks/archive/constructor_results.csv"
constructor_standings_csv = "/content/drive/MyDrive/Colab Notebooks/archive/constructor_standings.csv"
constructors_csv= "/content/drive/MyDrive/Colab Notebooks/archive/constructors.csv"
qualifying_csv = "/content/drive/MyDrive/Colab Notebooks/archive/qualifying.csv"
results_csv = "/content/drive/MyDrive/Colab Notebooks/archive/results.csv"
sprint_results_csv = "/content/drive/MyDrive/Colab Notebooks/archive/sprint_results.csv"

races_df = pd.read_csv(races_csv)
constructor_results_df = pd.read_csv(constructor_results_csv)
constructor_standings_df = pd.read_csv(constructor_standings_csv)
constructors_df = pd.read_csv(constructors_csv)
qualifying_df = pd.read_csv(qualifying_csv)
results_df = pd.read_csv(results_csv)
sprint_results_df = pd.read_csv(sprint_results_csv)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(races_df.columns)
def prepare_races(races_df):
  races_df = races_df[['raceId', 'year', 'round', 'circuitId', 'name']].copy()
  return races_df
display(prepare_races(races_df))
# Out:
# Index(['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url',
#        'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time',
#        'quali_date', 'quali_time', 'sprint_date', 'sprint_time'],
#       dtype='object')
#       raceId  year  round  circuitId                    name
# 0          1  2009      1          1   Australian Grand Prix
# 1          2  2009      2          2    Malaysian Grand Prix
# 2          3  2009      3         17      Chinese Grand Prix
# 3          4  2009      4          3      Bahrain Grand Prix
# 4          5  2009      5          4      Spanish Grand Prix
# ...      ...   ...    ...        ...                     ...
# 1120    1140  2024     20         32  Mexico City Grand Prix
# 1121    1141  2024     21         18    São Paulo Grand Prix
# 1122    1142  2024     22         80    Las Vegas Grand Prix
# 1123    1143  2024     23         78        Qatar Grand Prix
# 1124    1144  2024     24         24    Abu Dhabi Grand Prix
#
# [1125 rows x 5 columns]

# %%
print(constructor_results_df.columns)
def prepare_constructor_results(constructor_results_df):
  constructor_results_df = results_df[['constructorId', 'raceId', 'points']].copy() # not taking 'status'
  print(1)
  return constructor_results_df

display(prepare_constructor_results(constructor_results_df))
# Out:
# Index(['constructorResultsId', 'raceId', 'constructorId', 'points', 'status'], dtype='object')
# 1
#        constructorId  raceId  points
# 0                  1      18    10.0
# 1                  2      18     8.0
# 2                  3      18     6.0
# 3                  4      18     5.0
# 4                  1      18     4.0
# ...              ...     ...     ...
# 26754            210    1144     0.0
# 26755            215    1144     0.0
# 26756             15    1144     0.0
# 26757              3    1144     0.0
# 26758              9    1144     0.0
#
# [26759 rows x 3 columns]

# %%
print(constructor_standings_df.columns)
def prepare_constructor_standings(constructor_standings_df):
  constructor_standings_df = constructor_standings_df[['constructorId', 'raceId', 'points', 'position', 'wins']].copy()
  return constructor_standings_df
display(prepare_constructor_standings(constructor_standings_df))
# Out:
# Index(['constructorStandingsId', 'raceId', 'constructorId', 'points',
#        'position', 'positionText', 'wins'],
#       dtype='object')
#        constructorId  raceId  points  position  wins
# 0                  1      18    14.0         1     1
# 1                  2      18     8.0         3     0
# 2                  3      18     9.0         2     0
# 3                  4      18     5.0         4     0
# 4                  5      18     2.0         5     0
# ...              ...     ...     ...       ...   ...
# 13386             15    1144     4.0        10     0
# 13387            210    1144    58.0         7     0
# 13388            215    1144    46.0         8     0
# 13389              3    1144    17.0         9     0
# 13390            214    1144    65.0         6     0
#
# [13391 rows x 5 columns]

# %%
print(constructors_df.columns)
def prepare_constructors(constructors_df):
  constructors_df = constructors_df[['constructorId', 'constructorRef', 'name', 'nationality']].copy()
  return constructors_df
display(prepare_constructors(constructors_df))
# Out:
# Index(['constructorId', 'constructorRef', 'name', 'nationality', 'url'], dtype='object')
#      constructorId constructorRef            name nationality
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
# 211            215             rb      RB F1 Team     Italian
#
# [212 rows x 4 columns]

# %%
print(qualifying_df.columns)
def prepare_qualifying(qualifying_df):
  qualifying_df = qualifying_df[['raceId', 'constructorId', 'position', 'q1', 'q2', 'q3']].copy()
  return qualifying_df
display(prepare_qualifying(qualifying_df))
# Out:
# Index(['qualifyId', 'raceId', 'driverId', 'constructorId', 'number',
#        'position', 'q1', 'q2', 'q3'],
#       dtype='object')
#        raceId  constructorId  position        q1        q2        q3
# 0          18              1         1  1:26.572  1:25.187  1:26.714
# 1          18              2         2  1:26.103  1:25.315  1:26.869
# 2          18              1         3  1:25.664  1:25.452  1:27.079
# 3          18              6         4  1:25.994  1:25.691  1:27.178
# 4          18              2         5  1:25.960  1:25.518  1:27.236
# ...       ...            ...       ...       ...       ...       ...
# 10489    1144              3        16  1:23.821        \N        \N
# 10490    1144             15        17  1:23.880        \N        \N
# 10491    1144            131        18  1:23.887        \N        \N
# 10492    1144              3        19  1:23.912        \N        \N
# 10493    1144            214        20  1:24.105        \N        \N
#
# [10494 rows x 6 columns]

# %%
print(results_df.columns)
def prepare_results(results_df):
  results_df = results_df[['raceId', 'constructorId', 'grid', 'positionOrder', 'points', 'laps', 'time', 'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
       'fastestLapSpeed']].copy()
  return results_df
display(prepare_results(results_df))
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid',
#        'position', 'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId'],
#       dtype='object')
#        raceId  constructorId  grid  positionOrder  points  laps         time  \
# 0          18              1     1              1    10.0    58  1:34:50.616
# 1          18              2     5              2     8.0    58       +5.478
# 2          18              3     7              3     6.0    58       +8.163
# 3          18              4    11              4     5.0    58      +17.181
# 4          18              1     3              5     4.0    58      +18.014
# ...       ...            ...   ...            ...     ...   ...          ...
# 26754    1144            210    14             16     0.0    57           \N
# 26755    1144            215    12             17     0.0    55           \N
# 26756    1144             15     9             18     0.0    30           \N
# 26757    1144              3    20             19     0.0    26           \N
# 26758    1144              9    10             20     0.0     0           \N
#
#       milliseconds fastestLap rank fastestLapTime fastestLapSpeed
# 0          5690616         39    2       1:27.452         218.300
# 1          5696094         41    3       1:27.739         217.586
# 2          5698779         41    5       1:28.090         216.719
# 3          5707797         58    7       1:28.603         215.464
# 4          5708630         43    1       1:27.418         218.385
# ...            ...        ...  ...            ...             ...
# 26754           \N         57    1       1:25.637         222.002
# 26755           \N         52   12       1:28.751         214.212
# 26756           \N         14   19       1:29.482         212.462
# 26757           \N          5   17       1:29.411         212.631
# 26758           \N         \N    0             \N              \N
#
# [26759 rows x 12 columns]

# %%
# it is duplicated of result
print(sprint_results_df.columns)
def prepare_sprint_results(sprint_results_df):
  sprint_results_df = sprint_results_df[['raceId', 'constructorId', 'grid', 'positionOrder', 'points', 'laps', 'time', 'milliseconds', 'fastestLap']].copy()
  return sprint_results_df
display(prepare_sprint_results(sprint_results_df))
# Out:
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid',
#        'position', 'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'milliseconds', 'fastestLap', 'fastestLapTime', 'statusId'],
#       dtype='object')
#      raceId  constructorId  grid  positionOrder  points  laps       time  \
# 0      1061              9     2              1       3    17  25:38.426
# 1      1061            131     1              2       2    17     +1.430
# 2      1061            131     3              3       1    17     +7.502
# 3      1061              6     4              4       0    17    +11.278
# 4      1061              1     6              5       0    17    +24.111
# ..      ...            ...   ...            ...     ...   ...        ...
# 355    1143            215    10             16       0    19    +34.356
# 356    1143            215    16             17       0    19    +35.102
# 357    1143              3     0             18       0    19    +35.639
# 358    1143             15    18             19       0    19  +1:11.436
# 359    1143              9     0             20       0    19  +1:14.371
#
#     milliseconds fastestLap
# 0        1538426         14
# 1        1539856         17
# 2        1545928         17
# 3        1549704         16
# 4        1562537         16
# ..           ...        ...
# 355      1657366         18
# 356      1658112         17
# 357      1658649         18
# 358      1694446         19
# 359      1697381         18
#
# [360 rows x 9 columns]

# %%
merged_df = prepare_constructor_results(constructor_results_df)
display(merged_df)
merged_df = merged_df.merge(prepare_constructor_standings(constructor_standings_df), on=['constructorId', 'raceId'], how='inner')
display(merged_df)
merged_df = merged_df.merge(prepare_qualifying(qualifying_df), on=['raceId', 'constructorId'], how='inner')
display(merged_df)
merged_df = merged_df.merge(prepare_results(results_df), on=['raceId', 'constructorId'], how='inner')
display(merged_df)
# merged_df = merged_df.merge(prepare_sprint_results(sprint_results_df), on=['raceId', 'constructorId'], how='inner')
# display(merged_df)
merged_df = merged_df.merge(prepare_constructors(constructors_df), on='constructorId', how='inner')
merged_df = merged_df.merge(prepare_races(races_df), on='raceId', how='inner')

display(merged_df)
# Out:
# 1
#        constructorId  raceId  points
# 0                  1      18    10.0
# 1                  2      18     8.0
# 2                  3      18     6.0
# 3                  4      18     5.0
# 4                  1      18     4.0
# ...              ...     ...     ...
# 26754            210    1144     0.0
# 26755            215    1144     0.0
# 26756             15    1144     0.0
# 26757              3    1144     0.0
# 26758              9    1144     0.0
#
# [26759 rows x 3 columns]
#        constructorId  raceId  points_x  points_y  position  wins
# 0                  1      18      10.0      14.0         1     1
# 1                  2      18       8.0       8.0         3     0
# 2                  3      18       6.0       9.0         2     0
# 3                  4      18       5.0       5.0         4     0
# 4                  1      18       4.0      14.0         1     1
# ...              ...     ...       ...       ...       ...   ...
# 24887            210    1144       0.0      58.0         7     0
# 24888            215    1144       0.0      46.0         8     0
# 24889             15    1144       0.0       4.0        10     0
# 24890              3    1144       0.0      17.0         9     0
# 24891              9    1144       0.0     589.0         3     9
#
# [24892 rows x 6 columns]
#        constructorId  raceId  points_x  points_y  position_x  wins  \
# 0                  1      18      10.0      14.0           1     1
# 1                  1      18      10.0      14.0           1     1
# 2                  2      18       8.0       8.0           3     0
# 3                  2      18       8.0       8.0           3     0
# 4                  3      18       6.0       9.0           2     0
# ...              ...     ...       ...       ...         ...   ...
# 20768             15    1144       0.0       4.0          10     0
# 20769              3    1144       0.0      17.0           9     0
# 20770              3    1144       0.0      17.0           9     0
# 20771              9    1144       0.0     589.0           3     9
# 20772              9    1144       0.0     589.0           3     9
#
#        position_y        q1        q2        q3
# 0               1  1:26.572  1:25.187  1:26.714
# 1               3  1:25.664  1:25.452  1:27.079
# 2               2  1:26.103  1:25.315  1:26.869
# 3               5  1:25.960  1:25.518  1:27.236
# 4               7  1:26.295  1:26.059  1:28.687
# ...           ...       ...       ...       ...
# 20768          17  1:23.880        \N        \N
# 20769          16  1:23.821        \N        \N
# 20770          19  1:23.912        \N        \N
# 20771           5  1:23.516  1:22.998  1:22.945
# 20772          10  1:23.559  1:23.379  1:23.264
#
# [20773 rows x 10 columns]
#        constructorId  raceId  points_x  points_y  position_x  wins  \
# 0                  1      18      10.0      14.0           1     1
# 1                  1      18      10.0      14.0           1     1
# 2                  1      18      10.0      14.0           1     1
# 3                  1      18      10.0      14.0           1     1
# 4                  2      18       8.0       8.0           3     0
# ...              ...     ...       ...       ...         ...   ...
# 41536              3    1144       0.0      17.0           9     0
# 41537              9    1144       0.0     589.0           3     9
# 41538              9    1144       0.0     589.0           3     9
# 41539              9    1144       0.0     589.0           3     9
# 41540              9    1144       0.0     589.0           3     9
#
#        position_y        q1        q2        q3  grid  positionOrder  points  \
# 0               1  1:26.572  1:25.187  1:26.714     1              1    10.0
# 1               1  1:26.572  1:25.187  1:26.714     3              5     4.0
# 2               3  1:25.664  1:25.452  1:27.079     1              1    10.0
# 3               3  1:25.664  1:25.452  1:27.079     3              5     4.0
# 4               2  1:26.103  1:25.315  1:26.869     5              2     8.0
# ...           ...       ...       ...       ...   ...            ...     ...
# 41536          19  1:23.912        \N        \N    20             19     0.0
# 41537           5  1:23.516  1:22.998  1:22.945     4              6     8.0
# 41538           5  1:23.516  1:22.998  1:22.945    10             20     0.0
# 41539          10  1:23.559  1:23.379  1:23.264     4              6     8.0
# 41540          10  1:23.559  1:23.379  1:23.264    10             20     0.0
#
#        laps         time milliseconds fastestLap rank fastestLapTime  \
# 0        58  1:34:50.616      5690616         39    2       1:27.452
# 1        58      +18.014      5708630         43    1       1:27.418
# 2        58  1:34:50.616      5690616         39    2       1:27.452
# 3        58      +18.014      5708630         43    1       1:27.418
# 4        58       +5.478      5696094         41    3       1:27.739
# ...     ...          ...          ...        ...  ...            ...
# 41536    26           \N           \N          5   17       1:29.411
# 41537    58      +49.847      5243138         56    6       1:27.765
# 41538     0           \N           \N         \N    0             \N
# 41539    58      +49.847      5243138         56    6       1:27.765
# 41540     0           \N           \N         \N    0             \N
#
#       fastestLapSpeed
# 0             218.300
# 1             218.385
# 2             218.300
# 3             218.385
# 4             217.586
# ...               ...
# 41536         212.631
# 41537         216.619
# 41538              \N
# 41539         216.619
# 41540              \N
#
# [41541 rows x 20 columns]
#        constructorId  raceId  points_x  points_y  position_x  wins  \
# 0                  1      18      10.0      14.0           1     1
# 1                  1      18      10.0      14.0           1     1
# 2                  1      18      10.0      14.0           1     1
# 3                  1      18      10.0      14.0           1     1
# 4                  2      18       8.0       8.0           3     0
# ...              ...     ...       ...       ...         ...   ...
# 41536              3    1144       0.0      17.0           9     0
# 41537              9    1144       0.0     589.0           3     9
# 41538              9    1144       0.0     589.0           3     9
# 41539              9    1144       0.0     589.0           3     9
# 41540              9    1144       0.0     589.0           3     9
#
#        position_y        q1        q2        q3  ...  rank  fastestLapTime  \
# 0               1  1:26.572  1:25.187  1:26.714  ...     2        1:27.452
# 1               1  1:26.572  1:25.187  1:26.714  ...     1        1:27.418
# 2               3  1:25.664  1:25.452  1:27.079  ...     2        1:27.452
# 3               3  1:25.664  1:25.452  1:27.079  ...     1        1:27.418
# 4               2  1:26.103  1:25.315  1:26.869  ...     3        1:27.739
# ...           ...       ...       ...       ...  ...   ...             ...
# 41536          19  1:23.912        \N        \N  ...    17        1:29.411
# 41537           5  1:23.516  1:22.998  1:22.945  ...     6        1:27.765
# 41538           5  1:23.516  1:22.998  1:22.945  ...     0              \N
# 41539          10  1:23.559  1:23.379  1:23.264  ...     6        1:27.765
# 41540          10  1:23.559  1:23.379  1:23.264  ...     0              \N
#
#        fastestLapSpeed  constructorRef      name_x nationality  year round  \
# 0              218.300         mclaren     McLaren     British  2008     1
# 1              218.385         mclaren     McLaren     British  2008     1
# 2              218.300         mclaren     McLaren     British  2008     1
# 3              218.385         mclaren     McLaren     British  2008     1
# 4              217.586      bmw_sauber  BMW Sauber      German  2008     1
# ...                ...             ...         ...         ...   ...   ...
# 41536          212.631        williams    Williams     British  2024    24
# 41537          216.619        red_bull    Red Bull    Austrian  2024    24
# 41538               \N        red_bull    Red Bull    Austrian  2024    24
# 41539          216.619        red_bull    Red Bull    Austrian  2024    24
# 41540               \N        red_bull    Red Bull    Austrian  2024    24
#
#       circuitId                 name_y
# 0             1  Australian Grand Prix
# 1             1  Australian Grand Prix
# 2             1  Australian Grand Prix
# 3             1  Australian Grand Prix
# 4             1  Australian Grand Prix
# ...         ...                    ...
# 41536        24   Abu Dhabi Grand Prix
# 41537        24   Abu Dhabi Grand Prix
# 41538        24   Abu Dhabi Grand Prix
# 41539        24   Abu Dhabi Grand Prix
# 41540        24   Abu Dhabi Grand Prix
#
# [41541 rows x 27 columns]

# %%
print(merged_df.isnull().sum())
# Out:
# raceId                             0
# circuitId                          0
# year                               0
# driverId                           0
# constructorId                      0
# grid                               0
# positionOrder                      0
# laps_led_last_3_races          25379
# best_lap_milliseconds          14419
# driver_wins_at_circuit         21285
# constructor_wins_at_circuit    15352
# dnf_rate_season                    0
# dtype: int64
